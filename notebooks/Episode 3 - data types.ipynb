# %% [markdown]
# ## Nan's
#
# https://data-lessons.github.io/library-python/03-data-types-and-format/
#
# 2016/11/18

# %%
import pandas as pd
articles_df = pd.read_csv('articles.csv')

# %%
articles_df.DOI.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 971     False
# 972     False
# 973     False
# 974     False
# 975     False
# 976     False
# 977     False
# 978     False
# 979     False
# 980     False
# 981     False
# 982     False
# 983     False
# 984     False
# 985     False
# 986     False
# 987     False
# 988     False
# 989     False
# 990     False
# 991     False
# 992     False
# 993     False
# 994     False
# 995     False
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: DOI, dtype: bool

# %%
print("number of articles without a DOI", 
      len(articles_df[articles_df.DOI.isnull()][['Title', 'DOI']]))
articles_df[articles_df.DOI.isnull()][['Title', 'DOI']]
# Out:
# number of articles without a DOI 23
#                                                  Title  DOI
# 95   Primality Testing and Factorization by using F...  NaN
# 96   Some Families of q-Series Identities and Assoc...  NaN
# 97   Zweier I-Convergent Double Sequence Spaces Def...  NaN
# 98   Initial Maclaurin Coecients Bounds for New Sub...  NaN
# 99   Measure of Tessellation Quality of Voronoï Meshes  NaN
# 100  Katsaras’s Type Fuzzy Norm under Triangular Norms  NaN
# 101  Some Perturbed Ostrowski Type Inequalities for...  NaN
# 102  Hadamard Product of Certain Harmonic Univalent...  NaN
# 103  New Čebyšev Type Inequalities for Functions wh...  NaN
# 104  A Mixed Integer Linear Programming Formulation...  NaN
# 105  PATH FINDER PROCESS VALIDATION OF MOIST HEAT S...  NaN
# 106  DRUG UTILIZATION PATTERN AND ADVERSE DRUG REAC...  NaN
# 107  EFFECT OF NITROGEN SOURCE FOR THE BIOSYNTHESIS...  NaN
# 108          BIOLOGICALLY ACTIVE PYRIMIDINE HYDARZONES  NaN
# ...

# %%
df1 = articles_df.copy()

# %%
df1['DOI'] = df1.DOI.fillna('Fish')

# %%
df1[df1.DOI == 'Fish'][['Title', 'DOI']]
# Out:
#                                                  Title   DOI
# 95   Primality Testing and Factorization by using F...  Fish
# 96   Some Families of q-Series Identities and Assoc...  Fish
# 97   Zweier I-Convergent Double Sequence Spaces Def...  Fish
# 98   Initial Maclaurin Coecients Bounds for New Sub...  Fish
# 99   Measure of Tessellation Quality of Voronoï Meshes  Fish
# 100  Katsaras’s Type Fuzzy Norm under Triangular Norms  Fish
# 101  Some Perturbed Ostrowski Type Inequalities for...  Fish
# 102  Hadamard Product of Certain Harmonic Univalent...  Fish
# 103  New Čebyšev Type Inequalities for Functions wh...  Fish
# 104  A Mixed Integer Linear Programming Formulation...  Fish
# 105  PATH FINDER PROCESS VALIDATION OF MOIST HEAT S...  Fish
# 106  DRUG UTILIZATION PATTERN AND ADVERSE DRUG REAC...  Fish
# 107  EFFECT OF NITROGEN SOURCE FOR THE BIOSYNTHESIS...  Fish
# 108          BIOLOGICALLY ACTIVE PYRIMIDINE HYDARZONES  Fish
# ...

# %%
articles_df[~articles_df.DOI.isnull()]
# Out:
#         id                                              Title  \
# 0        0   The Fisher Thermodynamics of Quasi-Probabilities
# 1        1  Aflatoxin Contamination of the Milk Supply: A ...
# 2        2  Metagenomic Analysis of Upwelling-Affected Bra...
# 3        3  Synthesis and Reactivity of a Cerium(III) Scor...
# 4        4  Performance and Uncertainty Evaluation of Snow...
# 5        5  Dihydrochalcone Compounds Isolated from Crabap...
# 6        6  Ionic Liquids as Carbene Catalyst Precursors i...
# 7        7  Characterization of Aspartate Kinase from Cory...
# 8        8  Quaternifications and Extensions of Current Al...
# 9        9            Imaging of HCC—Current State of the Art
# 10      10  Synthesis and Complexation of Well-Defined Lab...
# 11      11  UAV Control on the Basis of 3D Landmark Bearin...
# 12      12  Polar Glycosylated and Lateral Non-Glycosylate...
# 13      13  Selective Oxidation of Glycerol with 3% H2O2 C...
# ...
