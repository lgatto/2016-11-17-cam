# %% [markdown]
# ## Intro to pandas - Notebook for Episode 1
#
# 2016/11/17

# %%
import pandas as pd

# %%
articles_df = pd.read_csv('articles.csv')

# %%
articles_df
# Out:
#         id                                              Title  \
# 0        0   The Fisher Thermodynamics of Quasi-Probabilities
# 1        1  Aflatoxin Contamination of the Milk Supply: A ...
# 2        2  Metagenomic Analysis of Upwelling-Affected Bra...
# 3        3  Synthesis and Reactivity of a Cerium(III) Scor...
# 4        4  Performance and Uncertainty Evaluation of Snow...
# 5        5  Dihydrochalcone Compounds Isolated from Crabap...
# 6        6  Ionic Liquids as Carbene Catalyst Precursors i...
# 7        7  Characterization of Aspartate Kinase from Cory...
# 8        8  Quaternifications and Extensions of Current Al...
# 9        9            Imaging of HCC—Current State of the Art
# 10      10  Synthesis and Complexation of Well-Defined Lab...
# 11      11  UAV Control on the Basis of 3D Landmark Bearin...
# 12      12  Polar Glycosylated and Lateral Non-Glycosylate...
# 13      13  Selective Oxidation of Glycerol with 3% H2O2 C...
# ...

# %%
type(articles_df)
# Out:
# pandas.core.frame.DataFrame

# %%
my_string = "jkflsdjaljfld;"
type(my_string)
# Out:
# str

# %%
articles_df.columns
# Out:
# Index(['id', 'Title', 'Authors', 'DOI', 'URL', 'Subjects', 'ISSNs', 'Citation',
#        'LanguageId', 'LicenceId', 'Author_Count', 'First_Author',
#        'Citation_Count', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
articles_df.shape
# Out:
# (1001, 16)

# %%
articles_df.columns.values
# Out:
# array(['id', 'Title', 'Authors', 'DOI', 'URL', 'Subjects', 'ISSNs',
#        'Citation', 'LanguageId', 'LicenceId', 'Author_Count',
#        'First_Author', 'Citation_Count', 'Day', 'Month', 'Year'], dtype=object)

# %%
articles_df.Title
# Out:
# 0        The Fisher Thermodynamics of Quasi-Probabilities
# 1       Aflatoxin Contamination of the Milk Supply: A ...
# 2       Metagenomic Analysis of Upwelling-Affected Bra...
# 3       Synthesis and Reactivity of a Cerium(III) Scor...
# 4       Performance and Uncertainty Evaluation of Snow...
# 5       Dihydrochalcone Compounds Isolated from Crabap...
# 6       Ionic Liquids as Carbene Catalyst Precursors i...
# 7       Characterization of Aspartate Kinase from Cory...
# 8       Quaternifications and Extensions of Current Al...
# 9                 Imaging of HCC—Current State of the Art
# 10      Synthesis and Complexation of Well-Defined Lab...
# 11      UAV Control on the Basis of 3D Landmark Bearin...
# 12      Polar Glycosylated and Lateral Non-Glycosylate...
# 13      Selective Oxidation of Glycerol with 3% H2O2 C...
# 14      A Copper-Based Metal-Organic Framework as an E...
# 15      Performance-Based Cognitive Screening Instrume...
# ...

# %%
articles_df.Month.head(5)
# Out:
# 0    11
# 1    11
# 2    11
# 3    11
# 4    11
# Name: Month, dtype: int64

# %%
pd.unique(articles_df['Month'])
# Out:
# array([11, 12,  8,  4, 10,  9,  7,  6,  5,  3,  2,  1])

# %%
articles_df.Month.unique()
# Out:
# array([11, 12,  8,  4, 10,  9,  7,  6,  5,  3,  2,  1])

# %%
pub_count = len(articles_df.ISSNs.unique())
pub_count
# Out:
# 51

# %%
print(pub_count)
# Out:
# 51

# %%
articles_df.Citation_Count.describe()
# Out:
# count    1001.000000
# mean        9.023976
# std         1.655121
# min         3.000000
# 25%         9.000000
# 50%        10.000000
# 75%        10.000000
# max        10.000000
# Name: Citation_Count, dtype: float64

# %%
articles_df['Citation_Count'].describe()
# Out:
# count    1001.000000
# mean        9.023976
# std         1.655121
# min         3.000000
# 25%         9.000000
# 50%        10.000000
# 75%        10.000000
# max        10.000000
# Name: Citation_Count, dtype: float64

# %%
articles_df.describe()
# Out:
#                 id   LanguageId    LicenceId  Author_Count  Citation_Count  \
# count  1001.000000  1001.000000  1001.000000   1001.000000     1001.000000
# mean    500.000000     1.031968     1.074925      4.004995        9.023976
# std     289.108111     0.225781     0.383902      1.612754        1.655121
# min       0.000000     1.000000     1.000000      1.000000        3.000000
# 25%     250.000000     1.000000     1.000000      3.000000        9.000000
# 50%     500.000000     1.000000     1.000000      4.000000       10.000000
# 75%     750.000000     1.000000     1.000000      5.000000       10.000000
# max    1000.000000     4.000000     4.000000     16.000000       10.000000
#
#           Day        Month    Year
# count  1001.0  1001.000000  1001.0
# mean      1.0     6.447552  2015.0
# std       0.0     3.129137     0.0
# min       1.0     1.000000  2015.0
# 25%       1.0     4.000000  2015.0
# 50%       1.0     7.000000  2015.0
# 75%       1.0     9.000000  2015.0
# ...

# %%
byLang = articles_df.groupby('LanguageId')

# %%
byLang.describe()
# Out:
#                   Author_Count  Citation_Count    Day   LicenceId       Month  \
# LanguageId
# 1          count    978.000000      978.000000  978.0  978.000000  978.000000
#            mean       4.013292        9.137014    1.0    1.052147    6.332311
#            std        1.590281        1.497743    0.0    0.283169    3.072145
#            min        1.000000        3.000000    1.0    1.000000    1.000000
#            25%        3.000000        9.000000    1.0    1.000000    4.000000
#            50%        4.000000       10.000000    1.0    1.000000    6.000000
#            75%        5.000000       10.000000    1.0    1.000000    9.000000
#            max       16.000000       10.000000    1.0    4.000000   12.000000
# 2          count     15.000000       15.000000   15.0   15.000000   15.000000
#            mean       3.333333        4.333333    1.0    1.000000   11.000000
#            std        1.988060        0.487950    0.0    0.000000    0.000000
# ...

# %% [markdown]
# Summarize author counts for each publication (ISSNs) in your data. HINT: you can use the following syntax to only create summary statistics for one column in your data by_ISSNs['Author_Count'].describe()

# %%
by_ISSNs = articles_df.groupby('ISSNs')
by_ISSNs['Citation_Count'].describe()
# Out:
# ISSNs
# 0367-0449|1988-3250  count    11.0
#                      mean      4.0
#                      std       0.0
#                      min       4.0
#                      25%       4.0
#                      50%       4.0
#                      75%       4.0
#                      max       4.0
# 1099-4300            count     1.0
#                      mean      4.0
#                      std       NaN
#                      min       4.0
#                      25%       4.0
#                      50%       4.0
#                      75%       4.0
#                      max       4.0
# 1420-3049            count    10.0
#                      mean      4.0
#                      std       0.0
#                      min       4.0
#                      25%       4.0
#                      50%       4.0
#                      75%       4.0
#                      max       4.0
# 1422-0067            count     8.0
#                      mean      8.0
# ...

# %% [markdown]
# # count the number of samples by publisher
# article_counts = articles_df.groupby('ISSNs')['Title'].count()

# %%
by_ISSNs['Title'].count()
# Out:
# ISSNs
# 0367-0449|1988-3250     11
# 1099-4300                1
# 1420-3049               10
# 1422-0067                8
# 1424-8220                3
# 1660-3397                3
# 1660-4601                4
# 1996-1944                2
# 1999-4907                1
# 1999-4915                5
# 2056-9890              858
# 2067-2764|2247-6202     17
# 2071-1050                4
# 2072-4292                7
# 2072-6643                1
# 2072-6651                5
# 2072-6694                1
# 2073-4344                2
# 2073-4360                1
# 2073-4395                1
# 2073-4425                1
# 2073-4441                4
# 2073-8994                1
# 2075-163X                1
# 2075-1702                1
# 2075-4418                2
# 2075-4442                1
# 2075-4701                1
# 2075-5309                1
# 2076-0787                2
# 2076-2615                1
# 2076-3417                3
# 2076-3905                1
# 2076-393X                1
# ...

# %%
by_ISSNs['Title'].count()['2056-9890']
# Out:
# 858

# %%
articles_df['double_count'] = articles_df.Author_Count * 2

# %%
articles_df
# Out:
#         id                                              Title  \
# 0        0   The Fisher Thermodynamics of Quasi-Probabilities
# 1        1  Aflatoxin Contamination of the Milk Supply: A ...
# 2        2  Metagenomic Analysis of Upwelling-Affected Bra...
# 3        3  Synthesis and Reactivity of a Cerium(III) Scor...
# 4        4  Performance and Uncertainty Evaluation of Snow...
# 5        5  Dihydrochalcone Compounds Isolated from Crabap...
# 6        6  Ionic Liquids as Carbene Catalyst Precursors i...
# 7        7  Characterization of Aspartate Kinase from Cory...
# 8        8  Quaternifications and Extensions of Current Al...
# 9        9            Imaging of HCC—Current State of the Art
# 10      10  Synthesis and Complexation of Well-Defined Lab...
# 11      11  UAV Control on the Basis of 3D Landmark Bearin...
# 12      12  Polar Glycosylated and Lateral Non-Glycosylate...
# 13      13  Selective Oxidation of Glycerol with 3% H2O2 C...
# ...
